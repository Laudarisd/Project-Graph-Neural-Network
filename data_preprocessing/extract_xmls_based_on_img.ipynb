# %% [markdown]
# # Extract files corresponding to images

# %%
import os
import shutil
import xml.etree.ElementTree as ET
import glob

class XMLExtractor:
    def __init__(self, image_folders, xml_folder, output_folders):
        self.image_folders = image_folders
        self.xml_folder = xml_folder
        self.output_folders = output_folders

    def extract_xmls(self):
        for i, img_folder in enumerate(self.image_folders):
            output_folder = self.output_folders[i]
            self.check_folder_exists(output_folder)
            self.process_images(img_folder, output_folder)

    def process_images(self, img_folder, output_folder):
        img_filenames = set()
        for img_file in os.listdir(img_folder):
            img_filenames.add(os.path.splitext(img_file)[0])

        for xml_file in glob.glob(os.path.join(self.xml_folder, '*.xml')):
            root = ET.parse(xml_file).getroot()
            filename = root.find('filename').text
            if os.path.splitext(filename)[0] in img_filenames:
                output_xml_path = os.path.join(output_folder, os.path.basename(xml_file))
                shutil.copy(xml_file, output_xml_path)
                print(f"Copied {xml_file} to {output_xml_path}")

    def check_folder_exists(self, path):
        if not os.path.exists(path):
            try:
                os.makedirs(path)
                print(f'Created {path}')
            except OSError as e:
                if e.errno != errno.EEXIST:
                    raise

if __name__ == '__main__':
    image_folders = ['./raw_data_I_changed/raw_data/test/images',
                     './raw_data_I_changed/raw_data/train/images',
                     './raw_data_I_changed/raw_data/valid/images']
    xml_folder = './raw_data_I_changed/direction_xmls'
    output_folders = ['./raw_data_I_changed/raw_data/test/xmls',
                        './raw_data_I_changed/raw_data/train/xmls',
                        './raw_data_I_changed/raw_data/valid/xmls'
                      ]

    extractor = XMLExtractor(image_folders, xml_folder, output_folders)
    extractor.extract_xmls()
# Out:
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00004.xml to ./raw_data_I_changed/raw_data/test/xmls\TE_C_00004.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00009.xml to ./raw_data_I_changed/raw_data/test/xmls\TE_C_00009.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00018.xml to ./raw_data_I_changed/raw_data/test/xmls\TE_C_00018.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00023.xml to ./raw_data_I_changed/raw_data/test/xmls\TE_C_00023.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00004.xml to ./raw_data_I_changed/raw_data/test/xmls\TE_D_00004.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00033.xml to ./raw_data_I_changed/raw_data/test/xmls\TE_D_00033.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00035.xml to ./raw_data_I_changed/raw_data/test/xmls\TE_D_00035.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00017.xml to ./raw_data_I_changed/raw_data/test/xmls\TR_C_00017.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00022.xml to ./raw_data_I_changed/raw_data/test/xmls\TR_C_00022.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00025.xml to ./raw_data_I_changed/raw_data/test/xmls\TR_C_00025.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00026.xml to ./raw_data_I_changed/raw_data/test/xmls\TR_C_00026.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00054.xml to ./raw_data_I_changed/raw_data/test/xmls\TR_C_00054.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00067.xml to ./raw_data_I_changed/raw_data/test/xmls\TR_C_00067.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00068.xml to ./raw_data_I_changed/raw_data/test/xmls\TR_C_00068.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00072.xml to ./raw_data_I_changed/raw_data/test/xmls\TR_C_00072.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00075.xml to ./raw_data_I_changed/raw_data/test/xmls\TR_C_00075.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00087.xml to ./raw_data_I_changed/raw_data/test/xmls\TR_C_00087.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00092.xml to ./raw_data_I_changed/raw_data/test/xmls\TR_C_00092.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00119.xml to ./raw_data_I_changed/raw_data/test/xmls\TR_C_00119.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00128.xml to ./raw_data_I_changed/raw_data/test/xmls\TR_C_00128.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00132.xml to ./raw_data_I_changed/raw_data/test/xmls\TR_C_00132.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00002.xml to ./raw_data_I_changed/raw_data/test/xmls\TR_D_00002.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00023.xml to ./raw_data_I_changed/raw_data/test/xmls\TR_D_00023.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00024.xml to ./raw_data_I_changed/raw_data/test/xmls\TR_D_00024.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00098.xml to ./raw_data_I_changed/raw_data/test/xmls\TR_D_00098.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00120.xml to ./raw_data_I_changed/raw_data/test/xmls\TR_D_00120.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00149.xml to ./raw_data_I_changed/raw_data/test/xmls\TR_D_00149.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00168.xml to ./raw_data_I_changed/raw_data/test/xmls\TR_D_00168.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_M_00008.xml to ./raw_data_I_changed/raw_data/test/xmls\TR_M_00008.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_M_00010.xml to ./raw_data_I_changed/raw_data/test/xmls\TR_M_00010.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_C_00017.xml to ./raw_data_I_changed/raw_data/test/xmls\VA_C_00017.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_D_00012.xml to ./raw_data_I_changed/raw_data/test/xmls\VA_D_00012.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_D_00022.xml to ./raw_data_I_changed/raw_data/test/xmls\VA_D_00022.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_D_00033.xml to ./raw_data_I_changed/raw_data/test/xmls\VA_D_00033.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_M_00003.xml to ./raw_data_I_changed/raw_data/test/xmls\VA_M_00003.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00001.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_C_00001.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00002.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_C_00002.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00003.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_C_00003.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00005.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_C_00005.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00006.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_C_00006.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00007.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_C_00007.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00008.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_C_00008.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00010.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_C_00010.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00011.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_C_00011.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00012.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_C_00012.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00013.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_C_00013.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00014.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_C_00014.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00015.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_C_00015.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00017.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_C_00017.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00019.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_C_00019.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00021.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_C_00021.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00022.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_C_00022.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00024.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_C_00024.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00026.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_C_00026.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00027.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_C_00027.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00028.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_C_00028.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00029.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_C_00029.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00033.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_C_00033.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00034.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_C_00034.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00036.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_C_00036.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00001.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00001.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_000013.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_000013.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00002.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00002.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00003.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00003.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00005.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00005.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00006.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00006.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00007.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00007.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00008.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00008.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00010.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00010.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00012.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00012.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00014.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00014.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00015.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00015.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00016.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00016.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00018.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00018.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00019.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00019.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00020.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00020.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00021.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00021.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00022.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00022.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00023.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00023.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00024.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00024.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00026.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00026.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00029.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00029.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00030.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00030.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00031.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00031.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00032.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00032.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00036.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00036.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00037.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00037.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00038.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00038.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00039.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00039.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00040.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00040.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00044.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00044.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00045.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00045.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00046.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00046.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00047.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00047.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00048.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00048.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00049.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00049.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00050.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00050.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00051.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00051.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00052.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00052.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00053.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00053.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00054.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00054.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00056.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00056.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00058.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_D_00058.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_M_00005.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_M_00005.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_M_00006.xml to ./raw_data_I_changed/raw_data/train/xmls\TE_M_00006.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00002.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00002.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00003.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00003.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00004.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00004.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00006.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00006.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00007.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00007.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00008.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00008.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00009.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00009.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00010.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00010.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00011.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00011.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00012.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00012.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00013.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00013.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00015.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00015.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00016.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00016.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00021.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00021.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00023.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00023.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00024.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00024.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00029.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00029.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00030.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00030.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00031.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00031.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00032.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00032.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00034.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00034.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00035.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00035.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00038.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00038.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00039.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00039.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00040.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00040.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00042.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00042.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00045.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00045.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00047.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00047.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00048.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00048.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00049.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00049.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00053.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00053.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00055.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00055.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00056.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00056.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00058.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00058.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00059.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00059.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00063.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00063.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00066.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00066.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00069.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00069.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00070.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00070.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00073.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00073.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00074.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00074.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00076.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00076.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00078.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00078.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00079.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00079.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00080.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00080.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00081.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00081.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00082.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00082.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00083.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00083.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00084.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00084.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00085.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00085.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00086.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00086.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00089.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00089.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00090.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00090.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00091.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00091.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00093.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00093.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00094.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00094.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00096.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00096.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00098.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00098.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00101.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00101.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00103.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00103.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00104.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00104.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00105.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00105.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00106.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00106.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00107.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00107.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00111.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00111.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00117.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00117.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00120.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00120.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00121.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00121.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00123.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00123.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00125.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00125.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00129.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00129.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00130.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_C_00130.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00001.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00001.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00003.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00003.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00006.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00006.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00012.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00012.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00013.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00013.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00015.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00015.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00016.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00016.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00017.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00017.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00018.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00018.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00019.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00019.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00020.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00020.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00022.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00022.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00031.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00031.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00034.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00034.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00035.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00035.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00037.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00037.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00038.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00038.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00039.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00039.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00040.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00040.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00042.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00042.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00045.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00045.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00046.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00046.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00047.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00047.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00048.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00048.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00049.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00049.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00050.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00050.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00053.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00053.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00054.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00054.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00056.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00056.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00058.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00058.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00060.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00060.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00061.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00061.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00063.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00063.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00065.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00065.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00067.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00067.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00071.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00071.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00072.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00072.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00073.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00073.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00076.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00076.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00081.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00081.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00084.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00084.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00087.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00087.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00088.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00088.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00092.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00092.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00094.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00094.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00095.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00095.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00097.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00097.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00108.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00108.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00111.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00111.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00112.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00112.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00121.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00121.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00125.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00125.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00129.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00129.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00132.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00132.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00135.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00135.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00139.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00139.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00140.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00140.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00141.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00141.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00143.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00143.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00147.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00147.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00148.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00148.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00150.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00150.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00152.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00152.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00156.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00156.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00159.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00159.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00160.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00160.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00161.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00161.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00162.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00162.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00163.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00163.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00165.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00165.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00166.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00166.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00170.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00170.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00171.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_D_00171.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_M_00001.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_M_00001.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_M_00002.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_M_00002.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_M_00003.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_M_00003.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_M_00004.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_M_00004.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_M_00006.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_M_00006.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_M_00011.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_M_00011.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_M_00012.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_M_00012.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_M_00013.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_M_00013.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_M_00017.xml to ./raw_data_I_changed/raw_data/train/xmls\TR_M_00017.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_C_00006.xml to ./raw_data_I_changed/raw_data/train/xmls\VA_C_00006.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_C_00007.xml to ./raw_data_I_changed/raw_data/train/xmls\VA_C_00007.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_C_00008.xml to ./raw_data_I_changed/raw_data/train/xmls\VA_C_00008.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_C_00010.xml to ./raw_data_I_changed/raw_data/train/xmls\VA_C_00010.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_C_00011.xml to ./raw_data_I_changed/raw_data/train/xmls\VA_C_00011.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_C_00015.xml to ./raw_data_I_changed/raw_data/train/xmls\VA_C_00015.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_C_00018.xml to ./raw_data_I_changed/raw_data/train/xmls\VA_C_00018.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_C_00023.xml to ./raw_data_I_changed/raw_data/train/xmls\VA_C_00023.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_C_00026.xml to ./raw_data_I_changed/raw_data/train/xmls\VA_C_00026.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_C_00028.xml to ./raw_data_I_changed/raw_data/train/xmls\VA_C_00028.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_C_00030.xml to ./raw_data_I_changed/raw_data/train/xmls\VA_C_00030.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_C_00032.xml to ./raw_data_I_changed/raw_data/train/xmls\VA_C_00032.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_D_00001.xml to ./raw_data_I_changed/raw_data/train/xmls\VA_D_00001.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_D_00003.xml to ./raw_data_I_changed/raw_data/train/xmls\VA_D_00003.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_D_00005.xml to ./raw_data_I_changed/raw_data/train/xmls\VA_D_00005.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_D_00006.xml to ./raw_data_I_changed/raw_data/train/xmls\VA_D_00006.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_D_00007.xml to ./raw_data_I_changed/raw_data/train/xmls\VA_D_00007.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_D_00010.xml to ./raw_data_I_changed/raw_data/train/xmls\VA_D_00010.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_D_00019.xml to ./raw_data_I_changed/raw_data/train/xmls\VA_D_00019.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_D_00021.xml to ./raw_data_I_changed/raw_data/train/xmls\VA_D_00021.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_D_00023.xml to ./raw_data_I_changed/raw_data/train/xmls\VA_D_00023.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_D_00026.xml to ./raw_data_I_changed/raw_data/train/xmls\VA_D_00026.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_D_00027.xml to ./raw_data_I_changed/raw_data/train/xmls\VA_D_00027.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_D_00030.xml to ./raw_data_I_changed/raw_data/train/xmls\VA_D_00030.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_D_00034.xml to ./raw_data_I_changed/raw_data/train/xmls\VA_D_00034.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_D_00036.xml to ./raw_data_I_changed/raw_data/train/xmls\VA_D_00036.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_D_00037.xml to ./raw_data_I_changed/raw_data/train/xmls\VA_D_00037.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_M_00004.xml to ./raw_data_I_changed/raw_data/train/xmls\VA_M_00004.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00016.xml to ./raw_data_I_changed/raw_data/valid/xmls\TE_C_00016.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00020.xml to ./raw_data_I_changed/raw_data/valid/xmls\TE_C_00020.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00030.xml to ./raw_data_I_changed/raw_data/valid/xmls\TE_C_00030.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00031.xml to ./raw_data_I_changed/raw_data/valid/xmls\TE_C_00031.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00032.xml to ./raw_data_I_changed/raw_data/valid/xmls\TE_C_00032.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_C_00035.xml to ./raw_data_I_changed/raw_data/valid/xmls\TE_C_00035.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00009.xml to ./raw_data_I_changed/raw_data/valid/xmls\TE_D_00009.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00011.xml to ./raw_data_I_changed/raw_data/valid/xmls\TE_D_00011.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00017.xml to ./raw_data_I_changed/raw_data/valid/xmls\TE_D_00017.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00025.xml to ./raw_data_I_changed/raw_data/valid/xmls\TE_D_00025.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00027.xml to ./raw_data_I_changed/raw_data/valid/xmls\TE_D_00027.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00028.xml to ./raw_data_I_changed/raw_data/valid/xmls\TE_D_00028.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00034.xml to ./raw_data_I_changed/raw_data/valid/xmls\TE_D_00034.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00041.xml to ./raw_data_I_changed/raw_data/valid/xmls\TE_D_00041.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00042.xml to ./raw_data_I_changed/raw_data/valid/xmls\TE_D_00042.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00043.xml to ./raw_data_I_changed/raw_data/valid/xmls\TE_D_00043.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00055.xml to ./raw_data_I_changed/raw_data/valid/xmls\TE_D_00055.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_D_00057.xml to ./raw_data_I_changed/raw_data/valid/xmls\TE_D_00057.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_M_00001.xml to ./raw_data_I_changed/raw_data/valid/xmls\TE_M_00001.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_M_00002.xml to ./raw_data_I_changed/raw_data/valid/xmls\TE_M_00002.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_M_00003.xml to ./raw_data_I_changed/raw_data/valid/xmls\TE_M_00003.xml
# Copied ./raw_data_I_changed/direction_xmls\TE_M_00004.xml to ./raw_data_I_changed/raw_data/valid/xmls\TE_M_00004.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00014.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_C_00014.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00018.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_C_00018.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00028.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_C_00028.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00033.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_C_00033.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00036.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_C_00036.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00064.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_C_00064.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00065.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_C_00065.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00071.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_C_00071.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00077.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_C_00077.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00100.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_C_00100.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00108.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_C_00108.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_C_00122.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_C_00122.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00004.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_D_00004.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00005.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_D_00005.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00010.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_D_00010.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00027.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_D_00027.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00032.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_D_00032.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00043.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_D_00043.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00062.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_D_00062.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00068.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_D_00068.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00069.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_D_00069.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00091.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_D_00091.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00096.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_D_00096.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00099.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_D_00099.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00102.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_D_00102.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00107.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_D_00107.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00109.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_D_00109.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00110.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_D_00110.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00113.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_D_00113.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00116.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_D_00116.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00127.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_D_00127.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00128.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_D_00128.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00145.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_D_00145.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00153.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_D_00153.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00154.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_D_00154.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00155.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_D_00155.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_D_00173.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_D_00173.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_M_00005.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_M_00005.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_M_00007.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_M_00007.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_M_00015.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_M_00015.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_M_00018.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_M_00018.xml
# Copied ./raw_data_I_changed/direction_xmls\TR_M_00019.xml to ./raw_data_I_changed/raw_data/valid/xmls\TR_M_00019.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_C_00003.xml to ./raw_data_I_changed/raw_data/valid/xmls\VA_C_00003.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_C_00009.xml to ./raw_data_I_changed/raw_data/valid/xmls\VA_C_00009.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_C_00013.xml to ./raw_data_I_changed/raw_data/valid/xmls\VA_C_00013.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_C_00020.xml to ./raw_data_I_changed/raw_data/valid/xmls\VA_C_00020.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_C_00024.xml to ./raw_data_I_changed/raw_data/valid/xmls\VA_C_00024.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_D_00011.xml to ./raw_data_I_changed/raw_data/valid/xmls\VA_D_00011.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_M_00001.xml to ./raw_data_I_changed/raw_data/valid/xmls\VA_M_00001.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_M_00002.xml to ./raw_data_I_changed/raw_data/valid/xmls\VA_M_00002.xml
# Copied ./raw_data_I_changed/direction_xmls\VA_M_00005.xml to ./raw_data_I_changed/raw_data/valid/xmls\VA_M_00005.xml

# %% [markdown]
# # Split to train, test and valid.
# ## Condition: similar images and xmls stays in train folder

# %%
import os
import shutil
import xml.etree.ElementTree as ET
import glob
import math
import random

class DataSplitter:
    def __init__(self, similar_img_folder, unique_img_folder, similar_xml_folder, unique_xml_folder, output_folder):
        self.similar_img_folder = similar_img_folder
        self.unique_img_folder = unique_img_folder
        self.similar_xml_folder = similar_xml_folder
        self.unique_xml_folder = unique_xml_folder
        self.output_folder = output_folder
        self.total_files = 0

    def split_data(self):
        self.check_folder_exists(self.output_folder)
        train_folder = os.path.join(self.output_folder, 'train')
        valid_folder = os.path.join(self.output_folder, 'valid')
        test_folder = os.path.join(self.output_folder, 'test')

        self.check_folder_exists(train_folder)
        self.check_folder_exists(valid_folder)
        self.check_folder_exists(test_folder)

        train_img_folder = os.path.join(train_folder, 'images')
        train_xml_folder = os.path.join(train_folder, 'xmls')
        valid_img_folder = os.path.join(valid_folder, 'images')
        valid_xml_folder = os.path.join(valid_folder, 'xmls')
        test_img_folder = os.path.join(test_folder, 'images')
        test_xml_folder = os.path.join(test_folder, 'xmls')

        self.check_folder_exists(train_img_folder)
        self.check_folder_exists(train_xml_folder)
        self.check_folder_exists(valid_img_folder)
        self.check_folder_exists(valid_xml_folder)
        self.check_folder_exists(test_img_folder)
        self.check_folder_exists(test_xml_folder)

        # Copy similar and xmls_similar data to train
        self.copy_similar_data(train_img_folder, train_xml_folder)

        # Split unique and unique_xmls data into valid and test
        self.split_unique_data(train_img_folder, train_xml_folder, valid_img_folder, valid_xml_folder, test_img_folder, test_xml_folder)

        print(f"Total files processed: {self.total_files}")

    def copy_similar_data(self, train_img_folder, train_xml_folder):
        self.copy_files(self.similar_img_folder, train_img_folder)
        self.copy_files(self.similar_xml_folder, train_xml_folder, prefix='xmls_')

    def split_unique_data(self, train_img_folder, train_xml_folder, valid_img_folder, valid_xml_folder, test_img_folder, test_xml_folder):
        total_files = 176 + 186  # Similar + Unique
        train_count = 254 - 176  # 254 - similar
        valid_count = 73
        test_count = 35

        unique_img_files = self.get_all_image_files(self.unique_img_folder)
        unique_xml_files = self.get_all_xml_files(self.unique_xml_folder)
        random.shuffle(unique_img_files)
        random.shuffle(unique_xml_files)

        for i, img_file in enumerate(unique_img_files):
            img_path = os.path.join(self.unique_img_folder, img_file)
            xml_file = os.path.splitext(os.path.basename(img_file))[0] + '.xml'
            xml_path = os.path.join(self.unique_xml_folder, xml_file)

            if i < train_count:
                self.copy_files(img_path, train_img_folder)
                self.copy_files(xml_path, train_xml_folder)
            elif i < train_count + valid_count:
                self.copy_files(img_path, valid_img_folder)
                self.copy_files(xml_path, valid_xml_folder)
            else:
                self.copy_files(img_path, test_img_folder)
                self.copy_files(xml_path, test_xml_folder)

    def get_all_image_files(self, folder):
        image_files = []
        for filename in os.listdir(folder):
            if any(filename.endswith(ext) for ext in ['.jpg', '.jpeg', '.png', '.PNG', '.gif']):
                image_files.append(filename)
        return image_files

    def get_all_xml_files(self, folder):
        xml_files = []
        for filename in os.listdir(folder):
            if filename.endswith('.xml'):
                xml_files.append(filename)
        return xml_files

    def copy_files(self, src, dst, prefix=''):
        if os.path.isfile(src):
            dst_path = os.path.join(dst, prefix + os.path.basename(src))
            shutil.copy2(src, dst_path)
            self.total_files += 1
            print(f"Copied {src} to {dst_path}")

    def check_folder_exists(self, path):
        if not os.path.exists(path):
            try:
                os.makedirs(path)
                print(f'Created {path}')
            except OSError as e:
                if e.errno != errno.EEXIST:
                    raise

if __name__ == '__main__':
    similar_img_folder = './data/similar'
    unique_img_folder = './data/unique'
    similar_xml_folder = './data/xmls_similar'
    unique_xml_folder = './data/xmls_unique'
    output_folder = './raw_data'

    splitter = DataSplitter(similar_img_folder, unique_img_folder, similar_xml_folder, unique_xml_folder, output_folder)
    splitter.split_data()
# Out:
# Created ./raw_data
# Created ./raw_data\train
# Created ./raw_data\valid
# Created ./raw_data\test
# Created ./raw_data\train\images
# Created ./raw_data\train\xmls
# Created ./raw_data\valid\images
# Created ./raw_data\valid\xmls
# Created ./raw_data\test\images
# Created ./raw_data\test\xmls
# Copied ./data/unique\VA_C_00008.PNG to ./raw_data\train\images\VA_C_00008.PNG
# Copied ./data/xmls_unique\VA_C_00008.xml to ./raw_data\train\xmls\VA_C_00008.xml
# Copied ./data/unique\TE_C_00021.png to ./raw_data\train\images\TE_C_00021.png
# Copied ./data/xmls_unique\TE_C_00021.xml to ./raw_data\train\xmls\TE_C_00021.xml
# Copied ./data/unique\TR_C_00007.PNG to ./raw_data\train\images\TR_C_00007.PNG
# Copied ./data/xmls_unique\TR_C_00007.xml to ./raw_data\train\xmls\TR_C_00007.xml
# Copied ./data/unique\TR_C_00130.PNG to ./raw_data\train\images\TR_C_00130.PNG
# Copied ./data/xmls_unique\TR_C_00130.xml to ./raw_data\train\xmls\TR_C_00130.xml
# Copied ./data/unique\TR_D_00031.PNG to ./raw_data\train\images\TR_D_00031.PNG
# Copied ./data/xmls_unique\TR_D_00031.xml to ./raw_data\train\xmls\TR_D_00031.xml
# Copied ./data/unique\TR_D_00166.PNG to ./raw_data\train\images\TR_D_00166.PNG
# Copied ./data/xmls_unique\TR_D_00166.xml to ./raw_data\train\xmls\TR_D_00166.xml
# Copied ./data/unique\TR_D_00072.PNG to ./raw_data\train\images\TR_D_00072.PNG
# Copied ./data/xmls_unique\TR_D_00072.xml to ./raw_data\train\xmls\TR_D_00072.xml
# Copied ./data/unique\TR_D_00163.PNG to ./raw_data\train\images\TR_D_00163.PNG
# Copied ./data/xmls_unique\TR_D_00163.xml to ./raw_data\train\xmls\TR_D_00163.xml
# Copied ./data/unique\VA_D_00023.PNG to ./raw_data\train\images\VA_D_00023.PNG
# Copied ./data/xmls_unique\VA_D_00023.xml to ./raw_data\train\xmls\VA_D_00023.xml
# Copied ./data/unique\TR_D_00121.PNG to ./raw_data\train\images\TR_D_00121.PNG
# Copied ./data/xmls_unique\TR_D_00121.xml to ./raw_data\train\xmls\TR_D_00121.xml
# Copied ./data/unique\TE_D_00007.PNG to ./raw_data\train\images\TE_D_00007.PNG
# Copied ./data/xmls_unique\TE_D_00007.xml to ./raw_data\train\xmls\TE_D_00007.xml
# Copied ./data/unique\TR_C_00120.PNG to ./raw_data\train\images\TR_C_00120.PNG
# Copied ./data/xmls_unique\TR_C_00120.xml to ./raw_data\train\xmls\TR_C_00120.xml
# Copied ./data/unique\TR_C_00015.PNG to ./raw_data\train\images\TR_C_00015.PNG
# Copied ./data/xmls_unique\TR_C_00015.xml to ./raw_data\train\xmls\TR_C_00015.xml
# Copied ./data/unique\TR_C_00069.PNG to ./raw_data\train\images\TR_C_00069.PNG
# Copied ./data/xmls_unique\TR_C_00069.xml to ./raw_data\train\xmls\TR_C_00069.xml
# Copied ./data/unique\TR_M_00002.PNG to ./raw_data\train\images\TR_M_00002.PNG
# Copied ./data/xmls_unique\TR_M_00002.xml to ./raw_data\train\xmls\TR_M_00002.xml
# Copied ./data/unique\TR_M_00017.PNG to ./raw_data\train\images\TR_M_00017.PNG
# Copied ./data/xmls_unique\TR_M_00017.xml to ./raw_data\train\xmls\TR_M_00017.xml
# Copied ./data/unique\TR_D_00171.PNG to ./raw_data\train\images\TR_D_00171.PNG
# Copied ./data/xmls_unique\TR_D_00171.xml to ./raw_data\train\xmls\TR_D_00171.xml
# Copied ./data/unique\TR_C_00023.PNG to ./raw_data\train\images\TR_C_00023.PNG
# Copied ./data/xmls_unique\TR_C_00023.xml to ./raw_data\train\xmls\TR_C_00023.xml
# Copied ./data/unique\VA_D_00026.PNG to ./raw_data\train\images\VA_D_00026.PNG
# Copied ./data/xmls_unique\VA_D_00026.xml to ./raw_data\train\xmls\VA_D_00026.xml
# Copied ./data/unique\TE_C_00001.PNG to ./raw_data\train\images\TE_C_00001.PNG
# Copied ./data/xmls_unique\TE_C_00001.xml to ./raw_data\train\xmls\TE_C_00001.xml
# Copied ./data/unique\TE_D_00046.PNG to ./raw_data\train\images\TE_D_00046.PNG
# Copied ./data/xmls_unique\TE_D_00046.xml to ./raw_data\train\xmls\TE_D_00046.xml
# Copied ./data/unique\TE_D_00054.PNG to ./raw_data\train\images\TE_D_00054.PNG
# Copied ./data/xmls_unique\TE_D_00054.xml to ./raw_data\train\xmls\TE_D_00054.xml
# Copied ./data/unique\VA_D_00010.PNG to ./raw_data\train\images\VA_D_00010.PNG
# Copied ./data/xmls_unique\VA_D_00010.xml to ./raw_data\train\xmls\VA_D_00010.xml
# Copied ./data/unique\TR_M_00006.PNG to ./raw_data\train\images\TR_M_00006.PNG
# Copied ./data/xmls_unique\TR_M_00006.xml to ./raw_data\train\xmls\TR_M_00006.xml
# Copied ./data/unique\TR_C_00070.png to ./raw_data\train\images\TR_C_00070.png
# Copied ./data/xmls_unique\TR_C_00070.xml to ./raw_data\train\xmls\TR_C_00070.xml
# Copied ./data/unique\TR_D_00112.PNG to ./raw_data\train\images\TR_D_00112.PNG
# Copied ./data/xmls_unique\TR_D_00112.xml to ./raw_data\train\xmls\TR_D_00112.xml
# Copied ./data/unique\TR_C_00125.PNG to ./raw_data\train\images\TR_C_00125.PNG
# Copied ./data/xmls_unique\TR_C_00125.xml to ./raw_data\train\xmls\TR_C_00125.xml
# Copied ./data/unique\TR_D_00140.PNG to ./raw_data\train\images\TR_D_00140.PNG
# Copied ./data/xmls_unique\TR_D_00140.xml to ./raw_data\train\xmls\TR_D_00140.xml
# Copied ./data/unique\TR_C_00096.PNG to ./raw_data\train\images\TR_C_00096.PNG
# Copied ./data/xmls_unique\TR_C_00096.xml to ./raw_data\train\xmls\TR_C_00096.xml
# Copied ./data/unique\TR_C_00090.PNG to ./raw_data\train\images\TR_C_00090.PNG
# Copied ./data/xmls_unique\TR_C_00090.xml to ./raw_data\train\xmls\TR_C_00090.xml
# Copied ./data/unique\TE_D_00056.PNG to ./raw_data\train\images\TE_D_00056.PNG
# Copied ./data/xmls_unique\TE_D_00056.xml to ./raw_data\train\xmls\TE_D_00056.xml
# Copied ./data/unique\TR_D_00156.PNG to ./raw_data\train\images\TR_D_00156.PNG
# Copied ./data/xmls_unique\TR_D_00156.xml to ./raw_data\train\xmls\TR_D_00156.xml
# Copied ./data/unique\TE_D_00051.PNG to ./raw_data\train\images\TE_D_00051.PNG
# Copied ./data/xmls_unique\TE_D_00051.xml to ./raw_data\train\xmls\TE_D_00051.xml
# Copied ./data/unique\TR_M_00011.PNG to ./raw_data\train\images\TR_M_00011.PNG
# Copied ./data/xmls_unique\TR_M_00011.xml to ./raw_data\train\xmls\TR_M_00011.xml
# Copied ./data/unique\TE_D_00052.PNG to ./raw_data\train\images\TE_D_00052.PNG
# Copied ./data/xmls_unique\TE_D_00052.xml to ./raw_data\train\xmls\TE_D_00052.xml
# Copied ./data/unique\TR_C_00013.PNG to ./raw_data\train\images\TR_C_00013.PNG
# Copied ./data/xmls_unique\TR_C_00013.xml to ./raw_data\train\xmls\TR_C_00013.xml
# Copied ./data/unique\TR_C_00078.PNG to ./raw_data\train\images\TR_C_00078.PNG
# Copied ./data/xmls_unique\TR_C_00078.xml to ./raw_data\train\xmls\TR_C_00078.xml
# Copied ./data/unique\TE_D_00019.PNG to ./raw_data\train\images\TE_D_00019.PNG
# Copied ./data/xmls_unique\TE_D_00019.xml to ./raw_data\train\xmls\TE_D_00019.xml
# Copied ./data/unique\VA_D_00021.PNG to ./raw_data\train\images\VA_D_00021.PNG
# Copied ./data/xmls_unique\VA_D_00021.xml to ./raw_data\train\xmls\VA_D_00021.xml
# Copied ./data/unique\TR_C_00082.PNG to ./raw_data\train\images\TR_C_00082.PNG
# Copied ./data/xmls_unique\TR_C_00082.xml to ./raw_data\train\xmls\TR_C_00082.xml
# Copied ./data/unique\TR_D_00148.PNG to ./raw_data\train\images\TR_D_00148.PNG
# Copied ./data/xmls_unique\TR_D_00148.xml to ./raw_data\train\xmls\TR_D_00148.xml
# Copied ./data/unique\TR_C_00089.PNG to ./raw_data\train\images\TR_C_00089.PNG
# Copied ./data/xmls_unique\TR_C_00089.xml to ./raw_data\train\xmls\TR_C_00089.xml
# Copied ./data/unique\TR_C_00032.PNG to ./raw_data\train\images\TR_C_00032.PNG
# Copied ./data/xmls_unique\TR_C_00032.xml to ./raw_data\train\xmls\TR_C_00032.xml
# Copied ./data/unique\TE_D_00036.PNG to ./raw_data\train\images\TE_D_00036.PNG
# Copied ./data/xmls_unique\TE_D_00036.xml to ./raw_data\train\xmls\TE_D_00036.xml
# Copied ./data/unique\TR_D_00058.PNG to ./raw_data\train\images\TR_D_00058.PNG
# Copied ./data/xmls_unique\TR_D_00058.xml to ./raw_data\train\xmls\TR_D_00058.xml
# Copied ./data/unique\TE_C_00026.PNG to ./raw_data\train\images\TE_C_00026.PNG
# Copied ./data/xmls_unique\TE_C_00026.xml to ./raw_data\train\xmls\TE_C_00026.xml
# Copied ./data/unique\TR_C_00080.PNG to ./raw_data\train\images\TR_C_00080.PNG
# Copied ./data/xmls_unique\TR_C_00080.xml to ./raw_data\train\xmls\TR_C_00080.xml
# Copied ./data/unique\VA_C_00026.PNG to ./raw_data\train\images\VA_C_00026.PNG
# Copied ./data/xmls_unique\VA_C_00026.xml to ./raw_data\train\xmls\VA_C_00026.xml
# Copied ./data/unique\TR_C_00129.PNG to ./raw_data\train\images\TR_C_00129.PNG
# Copied ./data/xmls_unique\TR_C_00129.xml to ./raw_data\train\xmls\TR_C_00129.xml
# Copied ./data/unique\TE_D_00015.PNG to ./raw_data\train\images\TE_D_00015.PNG
# Copied ./data/xmls_unique\TE_D_00015.xml to ./raw_data\train\xmls\TE_D_00015.xml
# Copied ./data/unique\TR_C_00094.PNG to ./raw_data\train\images\TR_C_00094.PNG
# Copied ./data/xmls_unique\TR_C_00094.xml to ./raw_data\train\xmls\TR_C_00094.xml
# Copied ./data/unique\TR_C_00086.PNG to ./raw_data\train\images\TR_C_00086.PNG
# Copied ./data/xmls_unique\TR_C_00086.xml to ./raw_data\train\xmls\TR_C_00086.xml
# Copied ./data/unique\TR_C_00098.PNG to ./raw_data\train\images\TR_C_00098.PNG
# Copied ./data/xmls_unique\TR_C_00098.xml to ./raw_data\train\xmls\TR_C_00098.xml
# Copied ./data/unique\VA_C_00018.png to ./raw_data\train\images\VA_C_00018.png
# Copied ./data/xmls_unique\VA_C_00018.xml to ./raw_data\train\xmls\VA_C_00018.xml
# Copied ./data/unique\TR_C_00084.PNG to ./raw_data\train\images\TR_C_00084.PNG
# Copied ./data/xmls_unique\TR_C_00084.xml to ./raw_data\train\xmls\TR_C_00084.xml
# Copied ./data/unique\TE_M_00006.PNG to ./raw_data\train\images\TE_M_00006.PNG
# Copied ./data/xmls_unique\TE_M_00006.xml to ./raw_data\train\xmls\TE_M_00006.xml
# Copied ./data/unique\TR_C_00123.PNG to ./raw_data\train\images\TR_C_00123.PNG
# Copied ./data/xmls_unique\TR_C_00123.xml to ./raw_data\train\xmls\TR_C_00123.xml
# Copied ./data/unique\TR_C_00004.PNG to ./raw_data\train\images\TR_C_00004.PNG
# Copied ./data/xmls_unique\TR_C_00004.xml to ./raw_data\train\xmls\TR_C_00004.xml
# Copied ./data/unique\TR_C_00029.PNG to ./raw_data\train\images\TR_C_00029.PNG
# Copied ./data/xmls_unique\TR_C_00029.xml to ./raw_data\train\xmls\TR_C_00029.xml
# Copied ./data/unique\TR_M_00003.png to ./raw_data\train\images\TR_M_00003.png
# Copied ./data/xmls_unique\TR_M_00003.xml to ./raw_data\train\xmls\TR_M_00003.xml
# Copied ./data/unique\TR_D_00092.PNG to ./raw_data\train\images\TR_D_00092.PNG
# Copied ./data/xmls_unique\TR_D_00092.xml to ./raw_data\train\xmls\TR_D_00092.xml
# Copied ./data/unique\TE_D_00037.PNG to ./raw_data\train\images\TE_D_00037.PNG
# Copied ./data/xmls_unique\TE_D_00037.xml to ./raw_data\train\xmls\TE_D_00037.xml
# Copied ./data/unique\TE_C_00011.PNG to ./raw_data\train\images\TE_C_00011.PNG
# Copied ./data/xmls_unique\TE_C_00011.xml to ./raw_data\train\xmls\TE_C_00011.xml
# Copied ./data/unique\TE_C_00003.PNG to ./raw_data\train\images\TE_C_00003.PNG
# Copied ./data/xmls_unique\TE_C_00003.xml to ./raw_data\train\xmls\TE_C_00003.xml
# Copied ./data/unique\TR_D_00071.PNG to ./raw_data\train\images\TR_D_00071.PNG
# Copied ./data/xmls_unique\TR_D_00071.xml to ./raw_data\train\xmls\TR_D_00071.xml
# Copied ./data/unique\TR_C_00049.PNG to ./raw_data\train\images\TR_C_00049.PNG
# Copied ./data/xmls_unique\TR_C_00049.xml to ./raw_data\train\xmls\TR_C_00049.xml
# Copied ./data/unique\TR_D_00150.PNG to ./raw_data\train\images\TR_D_00150.PNG
# Copied ./data/xmls_unique\TR_D_00150.xml to ./raw_data\train\xmls\TR_D_00150.xml
# Copied ./data/unique\VA_D_00006.PNG to ./raw_data\train\images\VA_D_00006.PNG
# Copied ./data/xmls_unique\VA_D_00006.xml to ./raw_data\train\xmls\VA_D_00006.xml
# Copied ./data/unique\TE_D_00002.PNG to ./raw_data\train\images\TE_D_00002.PNG
# Copied ./data/xmls_unique\TE_D_00002.xml to ./raw_data\train\xmls\TE_D_00002.xml
# Copied ./data/unique\TR_D_00165.PNG to ./raw_data\train\images\TR_D_00165.PNG
# Copied ./data/xmls_unique\TR_D_00165.xml to ./raw_data\train\xmls\TR_D_00165.xml
# Copied ./data/unique\VA_D_00030.PNG to ./raw_data\train\images\VA_D_00030.PNG
# Copied ./data/xmls_unique\VA_D_00030.xml to ./raw_data\train\xmls\VA_D_00030.xml
# Copied ./data/unique\TR_C_00079.PNG to ./raw_data\train\images\TR_C_00079.PNG
# Copied ./data/xmls_unique\TR_C_00079.xml to ./raw_data\train\xmls\TR_C_00079.xml
# Copied ./data/unique\TE_C_00012.PNG to ./raw_data\train\images\TE_C_00012.PNG
# Copied ./data/xmls_unique\TE_C_00012.xml to ./raw_data\train\xmls\TE_C_00012.xml
# Copied ./data/unique\TR_D_00141.PNG to ./raw_data\train\images\TR_D_00141.PNG
# Copied ./data/xmls_unique\TR_D_00141.xml to ./raw_data\train\xmls\TR_D_00141.xml
# Copied ./data/unique\TR_C_00091.PNG to ./raw_data\train\images\TR_C_00091.PNG
# Copied ./data/xmls_unique\TR_C_00091.xml to ./raw_data\train\xmls\TR_C_00091.xml
# Copied ./data/unique\TR_C_00076.PNG to ./raw_data\train\images\TR_C_00076.PNG
# Copied ./data/xmls_unique\TR_C_00076.xml to ./raw_data\train\xmls\TR_C_00076.xml
# Copied ./data/unique\TE_D_00038.PNG to ./raw_data\train\images\TE_D_00038.PNG
# Copied ./data/xmls_unique\TE_D_00038.xml to ./raw_data\train\xmls\TE_D_00038.xml
# Copied ./data/unique\TR_D_00139.PNG to ./raw_data\train\images\TR_D_00139.PNG
# Copied ./data/xmls_unique\TR_D_00139.xml to ./raw_data\train\xmls\TR_D_00139.xml
# Copied ./data/unique\TR_D_00068.PNG to ./raw_data\valid\images\TR_D_00068.PNG
# Copied ./data/xmls_unique\TR_D_00068.xml to ./raw_data\valid\xmls\TR_D_00068.xml
# Copied ./data/unique\TE_D_00025.PNG to ./raw_data\valid\images\TE_D_00025.PNG
# Copied ./data/xmls_unique\TE_D_00025.xml to ./raw_data\valid\xmls\TE_D_00025.xml
# Copied ./data/unique\TE_M_00003.PNG to ./raw_data\valid\images\TE_M_00003.PNG
# Copied ./data/xmls_unique\TE_M_00003.xml to ./raw_data\valid\xmls\TE_M_00003.xml
# Copied ./data/unique\TE_D_00041.PNG to ./raw_data\valid\images\TE_D_00041.PNG
# Copied ./data/xmls_unique\TE_D_00041.xml to ./raw_data\valid\xmls\TE_D_00041.xml
# Copied ./data/unique\VA_M_00001.PNG to ./raw_data\valid\images\VA_M_00001.PNG
# Copied ./data/xmls_unique\VA_M_00001.xml to ./raw_data\valid\xmls\VA_M_00001.xml
# Copied ./data/unique\TE_D_00043.PNG to ./raw_data\valid\images\TE_D_00043.PNG
# Copied ./data/xmls_unique\TE_D_00043.xml to ./raw_data\valid\xmls\TE_D_00043.xml
# Copied ./data/unique\TR_D_00107.PNG to ./raw_data\valid\images\TR_D_00107.PNG
# Copied ./data/xmls_unique\TR_D_00107.xml to ./raw_data\valid\xmls\TR_D_00107.xml
# Copied ./data/unique\TR_D_00062.PNG to ./raw_data\valid\images\TR_D_00062.PNG
# Copied ./data/xmls_unique\TR_D_00062.xml to ./raw_data\valid\xmls\TR_D_00062.xml
# Copied ./data/unique\TR_C_00018.PNG to ./raw_data\valid\images\TR_C_00018.PNG
# Copied ./data/xmls_unique\TR_C_00018.xml to ./raw_data\valid\xmls\TR_C_00018.xml
# Copied ./data/unique\TE_D_00057.PNG to ./raw_data\valid\images\TE_D_00057.PNG
# Copied ./data/xmls_unique\TE_D_00057.xml to ./raw_data\valid\xmls\TE_D_00057.xml
# Copied ./data/unique\TR_D_00099.PNG to ./raw_data\valid\images\TR_D_00099.PNG
# Copied ./data/xmls_unique\TR_D_00099.xml to ./raw_data\valid\xmls\TR_D_00099.xml
# Copied ./data/unique\VA_C_00003.PNG to ./raw_data\valid\images\VA_C_00003.PNG
# Copied ./data/xmls_unique\VA_C_00003.xml to ./raw_data\valid\xmls\VA_C_00003.xml
# Copied ./data/unique\TR_D_00155.PNG to ./raw_data\valid\images\TR_D_00155.PNG
# Copied ./data/xmls_unique\TR_D_00155.xml to ./raw_data\valid\xmls\TR_D_00155.xml
# Copied ./data/unique\TR_D_00153.PNG to ./raw_data\valid\images\TR_D_00153.PNG
# Copied ./data/xmls_unique\TR_D_00153.xml to ./raw_data\valid\xmls\TR_D_00153.xml
# Copied ./data/unique\TR_C_00036.PNG to ./raw_data\valid\images\TR_C_00036.PNG
# Copied ./data/xmls_unique\TR_C_00036.xml to ./raw_data\valid\xmls\TR_C_00036.xml
# Copied ./data/unique\TR_M_00005.PNG to ./raw_data\valid\images\TR_M_00005.PNG
# Copied ./data/xmls_unique\TR_M_00005.xml to ./raw_data\valid\xmls\TR_M_00005.xml
# Copied ./data/unique\TR_C_00014.PNG to ./raw_data\valid\images\TR_C_00014.PNG
# Copied ./data/xmls_unique\TR_C_00014.xml to ./raw_data\valid\xmls\TR_C_00014.xml
# Copied ./data/unique\TE_C_00030.PNG to ./raw_data\valid\images\TE_C_00030.PNG
# Copied ./data/xmls_unique\TE_C_00030.xml to ./raw_data\valid\xmls\TE_C_00030.xml
# Copied ./data/unique\TE_C_00016.PNG to ./raw_data\valid\images\TE_C_00016.PNG
# Copied ./data/xmls_unique\TE_C_00016.xml to ./raw_data\valid\xmls\TE_C_00016.xml
# Copied ./data/unique\TR_C_00064.PNG to ./raw_data\valid\images\TR_C_00064.PNG
# Copied ./data/xmls_unique\TR_C_00064.xml to ./raw_data\valid\xmls\TR_C_00064.xml
# Copied ./data/unique\TR_D_00004.PNG to ./raw_data\valid\images\TR_D_00004.PNG
# Copied ./data/xmls_unique\TR_D_00004.xml to ./raw_data\valid\xmls\TR_D_00004.xml
# Copied ./data/unique\VA_D_00011.PNG to ./raw_data\valid\images\VA_D_00011.PNG
# Copied ./data/xmls_unique\VA_D_00011.xml to ./raw_data\valid\xmls\VA_D_00011.xml
# Copied ./data/unique\TE_D_00009.PNG to ./raw_data\valid\images\TE_D_00009.PNG
# Copied ./data/xmls_unique\TE_D_00009.xml to ./raw_data\valid\xmls\TE_D_00009.xml
# Copied ./data/unique\TE_C_00031.PNG to ./raw_data\valid\images\TE_C_00031.PNG
# Copied ./data/xmls_unique\TE_C_00031.xml to ./raw_data\valid\xmls\TE_C_00031.xml
# Copied ./data/unique\TR_D_00027.PNG to ./raw_data\valid\images\TR_D_00027.PNG
# Copied ./data/xmls_unique\TR_D_00027.xml to ./raw_data\valid\xmls\TR_D_00027.xml
# Copied ./data/unique\TR_D_00043.PNG to ./raw_data\valid\images\TR_D_00043.PNG
# Copied ./data/xmls_unique\TR_D_00043.xml to ./raw_data\valid\xmls\TR_D_00043.xml
# Copied ./data/unique\TR_D_00154.PNG to ./raw_data\valid\images\TR_D_00154.PNG
# Copied ./data/xmls_unique\TR_D_00154.xml to ./raw_data\valid\xmls\TR_D_00154.xml
# Copied ./data/unique\VA_C_00009.PNG to ./raw_data\valid\images\VA_C_00009.PNG
# Copied ./data/xmls_unique\VA_C_00009.xml to ./raw_data\valid\xmls\VA_C_00009.xml
# Copied ./data/unique\TR_D_00128.PNG to ./raw_data\valid\images\TR_D_00128.PNG
# Copied ./data/xmls_unique\TR_D_00128.xml to ./raw_data\valid\xmls\TR_D_00128.xml
# Copied ./data/unique\TR_D_00005.PNG to ./raw_data\valid\images\TR_D_00005.PNG
# Copied ./data/xmls_unique\TR_D_00005.xml to ./raw_data\valid\xmls\TR_D_00005.xml
# Copied ./data/unique\TR_C_00065.PNG to ./raw_data\valid\images\TR_C_00065.PNG
# Copied ./data/xmls_unique\TR_C_00065.xml to ./raw_data\valid\xmls\TR_C_00065.xml
# Copied ./data/unique\TR_C_00033.PNG to ./raw_data\valid\images\TR_C_00033.PNG
# Copied ./data/xmls_unique\TR_C_00033.xml to ./raw_data\valid\xmls\TR_C_00033.xml
# Copied ./data/unique\TE_D_00017.PNG to ./raw_data\valid\images\TE_D_00017.PNG
# Copied ./data/xmls_unique\TE_D_00017.xml to ./raw_data\valid\xmls\TE_D_00017.xml
# Copied ./data/unique\TR_D_00069.PNG to ./raw_data\valid\images\TR_D_00069.PNG
# Copied ./data/xmls_unique\TR_D_00069.xml to ./raw_data\valid\xmls\TR_D_00069.xml
# Copied ./data/unique\TE_D_00042.PNG to ./raw_data\valid\images\TE_D_00042.PNG
# Copied ./data/xmls_unique\TE_D_00042.xml to ./raw_data\valid\xmls\TE_D_00042.xml
# Copied ./data/unique\TR_C_00100.PNG to ./raw_data\valid\images\TR_C_00100.PNG
# Copied ./data/xmls_unique\TR_C_00100.xml to ./raw_data\valid\xmls\TR_C_00100.xml
# Copied ./data/unique\TR_D_00173.PNG to ./raw_data\valid\images\TR_D_00173.PNG
# Copied ./data/xmls_unique\TR_D_00173.xml to ./raw_data\valid\xmls\TR_D_00173.xml
# Copied ./data/unique\TE_D_00027.PNG to ./raw_data\valid\images\TE_D_00027.PNG
# Copied ./data/xmls_unique\TE_D_00027.xml to ./raw_data\valid\xmls\TE_D_00027.xml
# Copied ./data/unique\TR_M_00019.PNG to ./raw_data\valid\images\TR_M_00019.PNG
# Copied ./data/xmls_unique\TR_M_00019.xml to ./raw_data\valid\xmls\TR_M_00019.xml
# Copied ./data/unique\TE_D_00011.PNG to ./raw_data\valid\images\TE_D_00011.PNG
# Copied ./data/xmls_unique\TE_D_00011.xml to ./raw_data\valid\xmls\TE_D_00011.xml
# Copied ./data/unique\TE_C_00020.PNG to ./raw_data\valid\images\TE_C_00020.PNG
# Copied ./data/xmls_unique\TE_C_00020.xml to ./raw_data\valid\xmls\TE_C_00020.xml
# Copied ./data/unique\TE_C_00035.PNG to ./raw_data\valid\images\TE_C_00035.PNG
# Copied ./data/xmls_unique\TE_C_00035.xml to ./raw_data\valid\xmls\TE_C_00035.xml
# Copied ./data/unique\TE_M_00001.PNG to ./raw_data\valid\images\TE_M_00001.PNG
# Copied ./data/xmls_unique\TE_M_00001.xml to ./raw_data\valid\xmls\TE_M_00001.xml
# Copied ./data/unique\VA_C_00024.PNG to ./raw_data\valid\images\VA_C_00024.PNG
# Copied ./data/xmls_unique\VA_C_00024.xml to ./raw_data\valid\xmls\VA_C_00024.xml
# Copied ./data/unique\TE_M_00002.PNG to ./raw_data\valid\images\TE_M_00002.PNG
# Copied ./data/xmls_unique\TE_M_00002.xml to ./raw_data\valid\xmls\TE_M_00002.xml
# Copied ./data/unique\TR_D_00110.PNG to ./raw_data\valid\images\TR_D_00110.PNG
# Copied ./data/xmls_unique\TR_D_00110.xml to ./raw_data\valid\xmls\TR_D_00110.xml
# Copied ./data/unique\TR_D_00109.PNG to ./raw_data\valid\images\TR_D_00109.PNG
# Copied ./data/xmls_unique\TR_D_00109.xml to ./raw_data\valid\xmls\TR_D_00109.xml
# Copied ./data/unique\VA_C_00020.PNG to ./raw_data\valid\images\VA_C_00020.PNG
# Copied ./data/xmls_unique\VA_C_00020.xml to ./raw_data\valid\xmls\VA_C_00020.xml
# Copied ./data/unique\TR_C_00071.png to ./raw_data\valid\images\TR_C_00071.png
# Copied ./data/xmls_unique\TR_C_00071.xml to ./raw_data\valid\xmls\TR_C_00071.xml
# Copied ./data/unique\TR_C_00108.PNG to ./raw_data\valid\images\TR_C_00108.PNG
# Copied ./data/xmls_unique\TR_C_00108.xml to ./raw_data\valid\xmls\TR_C_00108.xml
# Copied ./data/unique\TR_C_00122.PNG to ./raw_data\valid\images\TR_C_00122.PNG
# Copied ./data/xmls_unique\TR_C_00122.xml to ./raw_data\valid\xmls\TR_C_00122.xml
# Copied ./data/unique\TR_D_00096.PNG to ./raw_data\valid\images\TR_D_00096.PNG
# Copied ./data/xmls_unique\TR_D_00096.xml to ./raw_data\valid\xmls\TR_D_00096.xml
# Copied ./data/unique\TR_M_00015.PNG to ./raw_data\valid\images\TR_M_00015.PNG
# Copied ./data/xmls_unique\TR_M_00015.xml to ./raw_data\valid\xmls\TR_M_00015.xml
# Copied ./data/unique\TE_M_00004.PNG to ./raw_data\valid\images\TE_M_00004.PNG
# Copied ./data/xmls_unique\TE_M_00004.xml to ./raw_data\valid\xmls\TE_M_00004.xml
# Copied ./data/unique\TE_D_00028.PNG to ./raw_data\valid\images\TE_D_00028.PNG
# Copied ./data/xmls_unique\TE_D_00028.xml to ./raw_data\valid\xmls\TE_D_00028.xml
# Copied ./data/unique\TR_M_00018.PNG to ./raw_data\valid\images\TR_M_00018.PNG
# Copied ./data/xmls_unique\TR_M_00018.xml to ./raw_data\valid\xmls\TR_M_00018.xml
# Copied ./data/unique\TR_M_00007.png to ./raw_data\valid\images\TR_M_00007.png
# Copied ./data/xmls_unique\TR_M_00007.xml to ./raw_data\valid\xmls\TR_M_00007.xml
# Copied ./data/unique\VA_M_00005.PNG to ./raw_data\valid\images\VA_M_00005.PNG
# Copied ./data/xmls_unique\VA_M_00005.xml to ./raw_data\valid\xmls\VA_M_00005.xml
# Copied ./data/unique\TR_D_00116.PNG to ./raw_data\valid\images\TR_D_00116.PNG
# Copied ./data/xmls_unique\TR_D_00116.xml to ./raw_data\valid\xmls\TR_D_00116.xml
# Copied ./data/unique\TR_D_00102.PNG to ./raw_data\valid\images\TR_D_00102.PNG
# Copied ./data/xmls_unique\TR_D_00102.xml to ./raw_data\valid\xmls\TR_D_00102.xml
# Copied ./data/unique\VA_C_00013.PNG to ./raw_data\valid\images\VA_C_00013.PNG
# Copied ./data/xmls_unique\VA_C_00013.xml to ./raw_data\valid\xmls\VA_C_00013.xml
# Copied ./data/unique\TR_D_00032.PNG to ./raw_data\valid\images\TR_D_00032.PNG
# Copied ./data/xmls_unique\TR_D_00032.xml to ./raw_data\valid\xmls\TR_D_00032.xml
# Copied ./data/unique\TR_C_00028.PNG to ./raw_data\valid\images\TR_C_00028.PNG
# Copied ./data/xmls_unique\TR_C_00028.xml to ./raw_data\valid\xmls\TR_C_00028.xml
# Copied ./data/unique\TR_D_00145.PNG to ./raw_data\valid\images\TR_D_00145.PNG
# Copied ./data/xmls_unique\TR_D_00145.xml to ./raw_data\valid\xmls\TR_D_00145.xml
# Copied ./data/unique\TE_D_00034.PNG to ./raw_data\valid\images\TE_D_00034.PNG
# Copied ./data/xmls_unique\TE_D_00034.xml to ./raw_data\valid\xmls\TE_D_00034.xml
# Copied ./data/unique\TR_D_00113.PNG to ./raw_data\valid\images\TR_D_00113.PNG
# Copied ./data/xmls_unique\TR_D_00113.xml to ./raw_data\valid\xmls\TR_D_00113.xml
# Copied ./data/unique\VA_M_00002.PNG to ./raw_data\valid\images\VA_M_00002.PNG
# Copied ./data/xmls_unique\VA_M_00002.xml to ./raw_data\valid\xmls\VA_M_00002.xml
# Copied ./data/unique\TR_D_00127.PNG to ./raw_data\valid\images\TR_D_00127.PNG
# Copied ./data/xmls_unique\TR_D_00127.xml to ./raw_data\valid\xmls\TR_D_00127.xml
# Copied ./data/unique\TE_C_00032.PNG to ./raw_data\valid\images\TE_C_00032.PNG
# Copied ./data/xmls_unique\TE_C_00032.xml to ./raw_data\valid\xmls\TE_C_00032.xml
# Copied ./data/unique\TR_C_00077.PNG to ./raw_data\valid\images\TR_C_00077.PNG
# Copied ./data/xmls_unique\TR_C_00077.xml to ./raw_data\valid\xmls\TR_C_00077.xml
# Copied ./data/unique\TE_D_00055.PNG to ./raw_data\valid\images\TE_D_00055.PNG
# Copied ./data/xmls_unique\TE_D_00055.xml to ./raw_data\valid\xmls\TE_D_00055.xml
# Copied ./data/unique\TR_D_00010.PNG to ./raw_data\valid\images\TR_D_00010.PNG
# Copied ./data/xmls_unique\TR_D_00010.xml to ./raw_data\valid\xmls\TR_D_00010.xml
# Copied ./data/unique\TR_D_00091.PNG to ./raw_data\valid\images\TR_D_00091.PNG
# Copied ./data/xmls_unique\TR_D_00091.xml to ./raw_data\valid\xmls\TR_D_00091.xml
# Copied ./data/unique\TR_C_00067.PNG to ./raw_data\test\images\TR_C_00067.PNG
# Copied ./data/xmls_unique\TR_C_00067.xml to ./raw_data\test\xmls\TR_C_00067.xml
# Copied ./data/unique\TE_C_00018.png to ./raw_data\test\images\TE_C_00018.png
# Copied ./data/xmls_unique\TE_C_00018.xml to ./raw_data\test\xmls\TE_C_00018.xml
# Copied ./data/unique\TR_C_00068.PNG to ./raw_data\test\images\TR_C_00068.PNG
# Copied ./data/xmls_unique\TR_C_00068.xml to ./raw_data\test\xmls\TR_C_00068.xml
# Copied ./data/unique\TR_D_00024.PNG to ./raw_data\test\images\TR_D_00024.PNG
# Copied ./data/xmls_unique\TR_D_00024.xml to ./raw_data\test\xmls\TR_D_00024.xml
# Copied ./data/unique\TR_C_00119.PNG to ./raw_data\test\images\TR_C_00119.PNG
# Copied ./data/xmls_unique\TR_C_00119.xml to ./raw_data\test\xmls\TR_C_00119.xml
# Copied ./data/unique\TR_C_00087.PNG to ./raw_data\test\images\TR_C_00087.PNG
# Copied ./data/xmls_unique\TR_C_00087.xml to ./raw_data\test\xmls\TR_C_00087.xml
# Copied ./data/unique\TE_D_00004.PNG to ./raw_data\test\images\TE_D_00004.PNG
# Copied ./data/xmls_unique\TE_D_00004.xml to ./raw_data\test\xmls\TE_D_00004.xml
# Copied ./data/unique\TR_C_00092.PNG to ./raw_data\test\images\TR_C_00092.PNG
# Copied ./data/xmls_unique\TR_C_00092.xml to ./raw_data\test\xmls\TR_C_00092.xml
# Copied ./data/unique\TR_C_00025.PNG to ./raw_data\test\images\TR_C_00025.PNG
# Copied ./data/xmls_unique\TR_C_00025.xml to ./raw_data\test\xmls\TR_C_00025.xml
# Copied ./data/unique\TE_C_00023.PNG to ./raw_data\test\images\TE_C_00023.PNG
# Copied ./data/xmls_unique\TE_C_00023.xml to ./raw_data\test\xmls\TE_C_00023.xml
# Copied ./data/unique\TR_D_00168.PNG to ./raw_data\test\images\TR_D_00168.PNG
# Copied ./data/xmls_unique\TR_D_00168.xml to ./raw_data\test\xmls\TR_D_00168.xml
# Copied ./data/unique\TR_D_00149.PNG to ./raw_data\test\images\TR_D_00149.PNG
# Copied ./data/xmls_unique\TR_D_00149.xml to ./raw_data\test\xmls\TR_D_00149.xml
# Copied ./data/unique\TE_C_00004.PNG to ./raw_data\test\images\TE_C_00004.PNG
# Copied ./data/xmls_unique\TE_C_00004.xml to ./raw_data\test\xmls\TE_C_00004.xml
# Copied ./data/unique\TR_D_00002.PNG to ./raw_data\test\images\TR_D_00002.PNG
# Copied ./data/xmls_unique\TR_D_00002.xml to ./raw_data\test\xmls\TR_D_00002.xml
# Copied ./data/unique\TE_D_00033.PNG to ./raw_data\test\images\TE_D_00033.PNG
# Copied ./data/xmls_unique\TE_D_00033.xml to ./raw_data\test\xmls\TE_D_00033.xml
# Copied ./data/unique\TR_C_00132.PNG to ./raw_data\test\images\TR_C_00132.PNG
# Copied ./data/xmls_unique\TR_C_00132.xml to ./raw_data\test\xmls\TR_C_00132.xml
# Copied ./data/unique\TR_D_00120.PNG to ./raw_data\test\images\TR_D_00120.PNG
# Copied ./data/xmls_unique\TR_D_00120.xml to ./raw_data\test\xmls\TR_D_00120.xml
# Copied ./data/unique\TR_D_00098.PNG to ./raw_data\test\images\TR_D_00098.PNG
# Copied ./data/xmls_unique\TR_D_00098.xml to ./raw_data\test\xmls\TR_D_00098.xml
# Copied ./data/unique\TR_C_00026.PNG to ./raw_data\test\images\TR_C_00026.PNG
# Copied ./data/xmls_unique\TR_C_00026.xml to ./raw_data\test\xmls\TR_C_00026.xml
# Copied ./data/unique\VA_M_00003.PNG to ./raw_data\test\images\VA_M_00003.PNG
# Copied ./data/xmls_unique\VA_M_00003.xml to ./raw_data\test\xmls\VA_M_00003.xml
# Copied ./data/unique\VA_D_00033.PNG to ./raw_data\test\images\VA_D_00033.PNG
# Copied ./data/xmls_unique\VA_D_00033.xml to ./raw_data\test\xmls\VA_D_00033.xml
# Copied ./data/unique\TR_C_00022.PNG to ./raw_data\test\images\TR_C_00022.PNG
# Copied ./data/xmls_unique\TR_C_00022.xml to ./raw_data\test\xmls\TR_C_00022.xml
# Copied ./data/unique\TR_C_00075.png to ./raw_data\test\images\TR_C_00075.png
# Copied ./data/xmls_unique\TR_C_00075.xml to ./raw_data\test\xmls\TR_C_00075.xml
# Copied ./data/unique\VA_C_00017.PNG to ./raw_data\test\images\VA_C_00017.PNG
# Copied ./data/xmls_unique\VA_C_00017.xml to ./raw_data\test\xmls\VA_C_00017.xml
# Copied ./data/unique\TE_C_00009.PNG to ./raw_data\test\images\TE_C_00009.PNG
# Copied ./data/xmls_unique\TE_C_00009.xml to ./raw_data\test\xmls\TE_C_00009.xml
# Copied ./data/unique\TR_C_00072.PNG to ./raw_data\test\images\TR_C_00072.PNG
# Copied ./data/xmls_unique\TR_C_00072.xml to ./raw_data\test\xmls\TR_C_00072.xml
# Copied ./data/unique\TR_C_00054.PNG to ./raw_data\test\images\TR_C_00054.PNG
# Copied ./data/xmls_unique\TR_C_00054.xml to ./raw_data\test\xmls\TR_C_00054.xml
# Copied ./data/unique\VA_D_00022.PNG to ./raw_data\test\images\VA_D_00022.PNG
# Copied ./data/xmls_unique\VA_D_00022.xml to ./raw_data\test\xmls\VA_D_00022.xml
# Copied ./data/unique\TR_C_00128.PNG to ./raw_data\test\images\TR_C_00128.PNG
# Copied ./data/xmls_unique\TR_C_00128.xml to ./raw_data\test\xmls\TR_C_00128.xml
# Copied ./data/unique\TR_C_00017.PNG to ./raw_data\test\images\TR_C_00017.PNG
# Copied ./data/xmls_unique\TR_C_00017.xml to ./raw_data\test\xmls\TR_C_00017.xml
# Copied ./data/unique\TR_M_00008.PNG to ./raw_data\test\images\TR_M_00008.PNG
# Copied ./data/xmls_unique\TR_M_00008.xml to ./raw_data\test\xmls\TR_M_00008.xml
# Copied ./data/unique\TR_D_00023.PNG to ./raw_data\test\images\TR_D_00023.PNG
# Copied ./data/xmls_unique\TR_D_00023.xml to ./raw_data\test\xmls\TR_D_00023.xml
# Copied ./data/unique\TE_D_00035.PNG to ./raw_data\test\images\TE_D_00035.PNG
# Copied ./data/xmls_unique\TE_D_00035.xml to ./raw_data\test\xmls\TE_D_00035.xml
# Copied ./data/unique\TR_M_00010.PNG to ./raw_data\test\images\TR_M_00010.PNG
# Copied ./data/xmls_unique\TR_M_00010.xml to ./raw_data\test\xmls\TR_M_00010.xml
# Copied ./data/unique\VA_D_00012.PNG to ./raw_data\test\images\VA_D_00012.PNG
# Copied ./data/xmls_unique\VA_D_00012.xml to ./raw_data\test\xmls\VA_D_00012.xml
# Total files processed: 372
